# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
import time

#import functions as fn
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import make_scorer, r2_score, mean_squared_error, auc, mean_absolute_error, accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import RandomizedSearchCV, KFold, GridSearchCV
from sklearn.svm import SVC, SVR
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
        
from numpy.linalg import norm

# %%
def calculateReturns(prices, lag):
    
    #prices is a pandasDataFrame type
    prevPrices = prices.shift(lag)
    return ((prices - prevPrices) / prevPrices)

def thresh_func(x, lb, ub):
    
    if x <= lb:
        return 0
    elif lb < x < ub:
        return 1
    
    elif x > ub:
        return 2
    
    else:
        return np.nan

# %%
def ETF_predictions(ticker, MLmodel='rf', MLtype='regression'):
    
    ########################## DATA IMPORT ##############################################
    
    file=ticker + ".csv"
    
    df=pd.read_csv(file)
    df['date'] = pd.to_datetime(df['date'])
    df.sort_values(by=["PERMNO","date"], inplace=True)
    
    #Remove row where return=C and convert the rest of the column to float type
    #df['RET'] = np.where(df.RET == "C", 0, df.RET)
    df = df[df.RET != "C"]
    df['RET'] = df['RET'].astype(float)
    
    ########################## FEATURE ENGINEERING #######################################
    
    df["price"]=(df.ASK+df.BID)/2
    df["bidAskSpread"]=df.ASK-df.BID
    df["marketValue"] = df.SHROUT*df.price
    df["dollarVolume"] = df.VOL*df.price
    
    df["RET_1Mo"] = np.where(df.PERMNO == df.PERMNO.shift(21), (df.price-df.price.shift(21))/df.price.shift(21), np.nan)
    df["RET_3Mo"]  = np.where(df.PERMNO == df.PERMNO.shift(63), (df.price-df.price.shift(63))/df.price.shift(63), np.nan)
    df["RET_12Mo"]  = np.where(df.PERMNO == df.PERMNO.shift(253), (df.price-df.price.shift(253))/df.price.shift(253), np.nan)
    

    df["VolRET"] = np.where(df.PERMNO == df.PERMNO.shift(63), df.RET.rolling(window=63).std()*np.sqrt(253), np.nan)
   
    df["StdRET_12Mo"]=np.where(df.PERMNO == df.PERMNO.shift(253), df.RET.rolling(window=253).std(), np.nan)
    df["StdMARKET_12Mo"]=np.where(df.PERMNO == df.PERMNO.shift(253), df.sprtrn.rolling(window=253).std(), np.nan)
    df["CovRETMARKET_12Mo"]=np.where(df.PERMNO == df.PERMNO.shift(253),df.RET.rolling(window=253).cov(df.sprtrn.rolling(window=253)), np.nan)
    
    df["Beta_12Mo"]=df.CovRETMARKET_12Mo/(df.StdMARKET_12Mo**2)
    df["IvolRET_12Mo"]=np.sqrt((df.StdRET_12Mo**2-(df.Beta_12Mo*df.StdMARKET_12Mo)**2))*np.sqrt(253)
    df["BetaSq_12Mo"]=df.Beta_12Mo**2

    df["StdRET_3Mo"]=np.where(df.PERMNO == df.PERMNO.shift(63), df.RET.rolling(window=63).std(), np.nan)
    df["StdMARKET_3Mo"]=np.where(df.PERMNO == df.PERMNO.shift(63), df.sprtrn.rolling(window=63).std(), np.nan)
    df["CovRETMARKET_3Mo"]=np.where(df.PERMNO == df.PERMNO.shift(63),df.RET.rolling(window=63).cov(df.sprtrn.rolling(window=63)), np.nan)
    df["Beta_3Mo"]=df.CovRETMARKET_3Mo/(df.StdMARKET_3Mo**2)
    df["IvolRET_3Mo"]=np.sqrt((df.StdRET_3Mo**2-(df.Beta_3Mo*df.StdMARKET_3Mo)**2))*np.sqrt(253)
    df["BetaSq_3Mo"]=df.Beta_3Mo**2
    
    dfprice = df.price
    dfprice.index = df.date
    dfprice.replace([np.inf, -np.inf, np.NINF, -np.NINF], np.nan, inplace=True)
    
    df.drop(['PERMNO', 'date','PRC','BID','ASK', 'price'], axis=1, inplace=True)
    
    ########################## DATA PREPARATION ##############################################
    
    dates = dfprice.index
    #df_list = df_list
    mid = dfprice

    #holdingDays = 252 // 4; #hold a quarter
    holdingDays = 100
    #Returns
    Ret1 = calculateReturns(mid.copy(), 1).fillna(value=0)
    #20 week return
    RetQ = calculateReturns(mid.copy(), holdingDays) 

    #shifted next quarter's return to today's row to use as response variable. 
    #Can enter only at next day's close. 
    RetFut = RetQ.copy().shift(-(holdingDays+1))
    
    trainSize = 2014
    
    #flattening and repetition of the date vector
    flat_train = RetFut[:trainSize].size
    flat_test = RetFut[trainSize:].size
    flat = RetFut.size
    m0 = RetFut.shape[0] #original number of observations
    #nStocks = RetFut.shape[1] #original number of stocks

    datesTrain = dates.values[:trainSize].flatten()
    datesTest = dates.values[trainSize:].flatten()
    
    if MLtype == 'regression':
        Y0train = RetFut.values[:trainSize].flatten()[:,np.newaxis]
        Y0test = RetFut.values[trainSize:].flatten()[:,np.newaxis]
        
    elif MLtype == 'classification':
        a = RetFut.values
        lb = np.nanpercentile(a, 33)
        ub = np.nanpercentile(a, 66)
        Y = []
        for ret in RetFut:
            ret = thresh_func(ret, lb, ub)
            Y.append(ret)
        Yarray = np.array(Y).reshape(len(Y),1)
        Y0train = Yarray[:trainSize].flatten()[:,np.newaxis]
        Y0test = Yarray[trainSize:].flatten()[:,np.newaxis]
    
    #number of features - there are 23 features in total
    nInd = df.shape[1]
    
    X0train = np.zeros((flat_train, nInd))
    X0test = np.zeros((flat_test, nInd))
    X0 = np.zeros((flat, nInd))
    
    #######################
    #n = 0
    #df = df.values
    #X0train[:, n] = df[:trainSize].flatten()
    #X0test[:, n] = df[trainSize:].flatten()
    
    X0train = df.values[:trainSize]#.flatten()[:,np.newaxis]
    X0test = df.values[trainSize:]#.flatten()[:,np.newaxis]
    ########################
    
    dataCleanTrain = pd.DataFrame(np.hstack([X0train, Y0train]))
    dataCleanTrain.index = datesTrain
    
    dataCleanTest = pd.DataFrame(np.hstack([X0test, Y0test]))
    dataCleanTest.index = datesTest
    
    dataCleanTrain.replace([np.inf, -np.inf, np.NINF, -np.NINF], np.nan, inplace=True)
    dataCleanTest.replace([np.inf, -np.inf, np.NINF, -np.NINF], np.nan, inplace=True)
    
    dataCleanTrain.dropna(how='any', axis=0, inplace=True)
    dataCleanTest.dropna(how='any', axis=0, inplace=True)
    
    ixCleanTrain = dataCleanTrain.index.values
    ixCleanTest = dataCleanTest.index.values
    #print("First training day: {}".format(ixCleanTrain[0]))
    #print("Last training day: {}".format(ixCleanTrain[-1]))
    #print("First testing day: {}".format(ixCleanTest[0]))
    #print("Last testing day: {}".format(ixCleanTest[-1]))

    dataCleanTrain = dataCleanTrain.values
    dataCleanTest = dataCleanTest.values

    Xtrain, ytrain = dataCleanTrain[:, 0:-1], dataCleanTrain[:, -1][:,np.newaxis]
    Xtest, ytest = dataCleanTest[:, 0:-1], dataCleanTest[:, -1][:,np.newaxis]
    
    ########################## RF GRID ###########################################
    
    if MLmodel == 'rf':
        
        if MLtype == 'regression':
            model = RandomForestRegressor()
            
        elif MLtype == 'classification':
            model = RandomForestClassifier()
    
        np.random.seed(2)
        random_state=20

        # Create the pipe to tune

        pipe = Pipeline([("scaler",StandardScaler()),("sfm",SelectFromModel(model)),("rf",model)])

        #prepare parameter_grid

        # Number of trees in random forest
        n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]

        # Number of features to consider at every split
        max_features = [round(x,2) for x in np.linspace(start = 0.1, stop = 0.5, num = 5)]

        # Max depth of the tree
        max_depth = [2,3,4]
        
        # Level of threshold
        threshold = [".5*median", "median"]

        # Minimum number of samples required at each leaf node
        #min_samples_leaf = [int(x) for x in np.linspace(start = 15, stop = 100, num = 5)]

        # Method of selecting training subset for training each tree
        #bootstrap = [True]


        # Save these parameters in a dictionary
        param_grid = {'rf__n_estimators': n_estimators, 
                      'rf__max_features': max_features, 
                      'rf__max_depth': max_depth, 
                      'sfm__threshold': threshold
                      } 

        #Random search of parameters by searching across different combinations

        kfold = KFold(n_splits = 5, shuffle = True)
        rso = RandomizedSearchCV(pipe, 
                                       param_distributions = param_grid, 
                                       n_iter = 10,                               
                                       cv = kfold,
                                       random_state=random_state
                                       )
        # Fit the model to find the best hyperparameter values
        rso.fit(Xtrain, ytrain.ravel())

        print(rso.best_params_)
        #{'rf__max_features': 0.4, 'rf__min_samples_leaf': 15, 'rf__max_depth': 4, 'rf__bootstrap': True, 'sfm__threshold': 'median', 'rf__n_estimators': 225}

        # Assign the best model to best_random_forest
        best_random_forest = rso.best_estimator_

        # Initialize random_state, this is possible but it takes too long to do the search:
        best_random_forest.random_state = random_state 

        predictions = best_random_forest.predict(Xtest)
        predictions_train = best_random_forest.predict(Xtrain)

        #print('\n')
        #print("{} {} {} model\n".format(ticker, MLmodel, MLtype))
        #print("train accuracy: {:.4f}\ntest accuracy: {:.4f}\ntest error {:.4f}\n".format(accuracy_train, accuracy, error))

        
    ########################## SVM GRID ###########################################
        
    elif MLmodel == 'svm':
        
        if MLtype == 'classification':
            model = SVC()
            
        elif MLtype == 'regression':
            model = SVR()
            
        pipe = Pipeline([("scaler", MinMaxScaler()),("svm", model)])

        param_grid = [{'svm__kernel': ['rbf'], 
                       'svm__C': [0.001, 0.01, 0.1, 1, 10, 100], 
                        'svm__gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
                      {'svm__kernel': ['linear'],
                      'svm__C': [0.001, 0.01, 0.1, 1, 10, 100]},
                      {'svm__kernel': ['poly'],
                       'svm__degree': [0, 1, 2, 3, 4, 5, 6]}]

        grid_search = GridSearchCV(pipe, param_grid, iid=False, cv=5, return_train_score=True)

        grid_search.fit(Xtrain, ytrain)

        #results = pd.DataFrame(grid_search.cv_results_)
        #print(results.T)
        best_parameters = grid_search.best_params_
        print("Best parameters scaling grid: {}".format(best_parameters))
        print("Best cross-validation score scaling grid: {:.2f}".format(grid_search.best_score_*100)) #default is accuracy
        print("Test score scaling grid (grid object): {:.2f}\n".format(grid_search.score(Xtest,ytest)*100)) #default is accuracy

        results = pd.DataFrame(grid_search.cv_results_)
        #print(results.T)
        #results.to_csv("results_svc_norm.csv")
        
        #set up and run the model with the best parameters
        scl = MinMaxScaler()
        scl.fit(Xtrain)
        Xtrain = scl.transform(Xtrain)
        Xtest = scl.transform(Xtest)
        
        if MLtype == 'classification':
            if best_parameters['svm__kernel'] == 'rbf':
                cls = SVC(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__C'], 
                          gamma=best_parameters['svm__gamma'])

            elif best_parameters['svm__kernel'] == 'linear':
                cls = SVC(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__C'])

            elif best_parameters['svm__kernel'] == 'poly':
                cls = SVC(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__degree'])
                
        elif MLtype == 'regression':
            if best_parameters['svm__kernel'] == 'rbf':
                cls = SVR(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__C'], 
                          gamma=best_parameters['svm__gamma'])

            elif best_parameters['svm__kernel'] == 'linear':
                cls = SVR(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__C'])

            elif best_parameters['svm__kernel'] == 'poly':
                cls = SVR(kernel=best_parameters['svm__kernel'], C=best_parameters['svm__degree'])
                
        
        cls.fit(Xtrain, ytrain)
        
        predictions = cls.predict(Xtest)
        predictions_train = cls.predict(Xtrain)
        
        #if MLtype == 'classification':
        #    train_score = accuracy_score(ytrain, predictions_train)
        #    test_score = accuracy_score(ytest, predictions)
        
        #train_r2 = r2_score(ytrain, predictions_train)
        #test_r2 = r2_score(ytest, predictions)
        #error = mean_squared_error(ytest, predictions)
        
    ########################## GB GRID ###########################################
        
    elif MLmodel == 'gb':
        
        if MLtype == 'classification':
            model = GradientBoostingClassifier()
            pipe = Pipeline([("scaler", MinMaxScaler()),("gb", model)])
            
            param_grid = [{'gb__loss': ['deviance'],
                           'gb__n_estimators': [100, 500, 1000],
                           'gb__max_depth': [3, 5, 10]},
                         ]
            
        elif MLtype == 'regression':
            model = GradientBoostingRegressor()
            pipe = Pipeline([("scaler", MinMaxScaler()),("gb", model)])
            param_grid = [{'gb__loss': ['ls'],
                           'gb__n_estimators': [100, 500, 1000],
                           'gb__max_depth': [3, 5, 10]},
              
                          {'gb__loss': ['quantile'],
                           'gb__n_estimators': [100, 500, 1000],
                           'gb__max_depth': [3, 5, 10],
                           'gb__alpha': [0.9, 0.95, 0.99]}
                         ]

        grid_search = GridSearchCV(pipe, param_grid, iid=False, cv=5, return_train_score=True)

        grid_search.fit(Xtrain, ytrain)

        #results = pd.DataFrame(grid_search.cv_results_)
        #print(results.T)
        best_parameters = grid_search.best_params_
        print("Best parameters scaling grid: {}".format(best_parameters))
        print("Best cross-validation score scaling grid: {:.2f}".format(grid_search.best_score_*100)) #default is accuracy
        print("Test score scaling grid (grid object): {:.2f}\n".format(grid_search.score(Xtest,ytest)*100)) #default is accuracy
        
        #set up and run the model with the best parameters
        scl = MinMaxScaler()
        scl.fit(Xtrain)
        Xtrain = scl.transform(Xtrain)
        Xtest = scl.transform(Xtest)
        
        if MLtype == 'regression':
            
            if best_parameters['gb__loss'] == 'ls':
                cls = GradientBoostingRegressor(loss=best_parameters['gb__loss'], 
                                                n_estimators=best_parameters['gb__n_estimators'], 
                                                max_depth=best_parameters['gb__max_depth'])

            elif best_parameters['gb__loss'] == 'quantile':
                cls = GradientBoostingRegressor(loss=best_parameters['gb__loss'], 
                                                n_estimators=best_parameters['gb__n_estimators'], 
                                                max_depth=best_parameters['gb__max_depth'], 
                                                alpha=best_parameters['gb__alpha'])
                
        elif MLtype == 'classification':
            cls = GradientBoostingClassifier(loss=best_parameters['gb__loss'], 
                                               n_estimators=best_parameters['gb__n_estimators'], 
                                               max_depth=best_parameters['gb__max_depth'])

        cls.fit(Xtrain, ytrain)
        
        predictions = cls.predict(Xtest)
        predictions_train = cls.predict(Xtrain)
        
      
    #################################################################################
    
    train_r2 = r2_score(ytrain, predictions_train)
    test_r2 = r2_score(ytest, predictions) 
    error = mean_squared_error(ytest, predictions)
    
    if MLtype == 'classification':
        train_score = accuracy_score(ytrain, predictions_train)
        test_score = accuracy_score(ytest, predictions)
        
        df_scores = pd.DataFrame({ticker: {'train_accuracy': train_score, 'test_accuracy': test_score, 'trainr2': train_r2, 
                                           'testr2': test_r2, 'error': error}})
    else:
        df_scores = pd.DataFrame({ticker: {'trainr2': train_r2, 'testr2': test_r2, 'error': error}})
    
    print("{} {} {} model\n".format(ticker, MLmodel, MLtype))
    if MLtype == 'classification':
        print("Train accuracy: {:.2f}%".format(train_score*100))
        print("Test accuracy: {:.2f}%".format(test_score*100))
    print("Train r2 score: {:.4f}".format(train_r2))
    print("Test r2 score: {:.4f}".format(test_r2))
    print("Test MSE: {:.4f}".format(error))
     
    df_predictions = pd.DataFrame({ticker:predictions})
    df_train_predictions = pd.DataFrame({ticker:predictions_train})    
    
    return Xtrain, Xtest, df, dfprice, df_scores, df_predictions, df_train_predictions

# %%
def df_creator(tickers, MLmodel, MLtype, create_csv=True):

    predictions_dict = {}
    train_predictions_dict = {}
    dflist = []
    dflist_train = []
    dfscorelist = []

    for t in tickers:

        Xtrain, Xtest, df, dfprice, df_scores, df_predictions, df_train_predictions = ETF_predictions(t, MLmodel, MLtype)
        dflist.append(df_predictions)
        dflist_train.append(df_train_predictions)
        dfscorelist.append(df_scores)
        
    df_all = pd.concat(dflist, axis=1, ignore_index=True)
    df_all.columns = tickers

    df_all_train = pd.concat(dflist_train, axis=1, ignore_index=True)
    df_all_train.columns = tickers
    
    df_all_scores = pd.concat(dfscorelist, axis=1, ignore_index=True)
    df_all_scores.columns = tickers
    
    if create_csv == True:
        filename = MLmodel + '-' + MLtype + '-ETF-predictions.csv'
        filename2 = MLmodel + '-' + MLtype + '-ETF-train-predictions.csv'
        filename3 = MLmodel + '-' + MLtype + '-ETF-model-scores.csv'
        
        df_all.to_csv(filename)
        df_all_train.to_csv(filename2)
        df_all_scores.to_csv(filename3)

# %%
t1 = time.time()

# %%
tickers = ['FXU', 'GDX', 'KBE', 'RXI', 'VNQ', 'XLP', 'XRT', 'DIA', 'IHI', 'IYW', 'SHY', 'VIS', 'XLE', 'XLF', 'XLK', 'XLU', 
           'XLV', 'XLY', 'SIL']

# %%
# Run Gradient Boosting

#df_creator(tickers, 'gb', 'regression', create_csv=False)
#df_creator(tickers, 'gb', 'classification', create_csv=False)
# Out:
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 5, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 43.85
# Test score scaling grid (grid object): 26.43
#
# FXU gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 27.43%
# Train r2 score: 1.0000
# Test r2 score: -0.3949
# Test MSE: 0.9202
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 10, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 46.87
# Test score scaling grid (grid object): 30.67
#
# GDX gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 37.41%
# Train r2 score: 1.0000
# Test r2 score: -1.6390
# Test MSE: 0.9476
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 10, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 37.92
# Test score scaling grid (grid object): 39.65
#
# KBE gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 43.64%
# Train r2 score: 1.0000
# Test r2 score: -1.0278
# Test MSE: 1.0723
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 10, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 38.83
# Test score scaling grid (grid object): 56.36
#
# RXI gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 58.35%
# Train r2 score: 1.0000
# Test r2 score: -0.3255
# Test MSE: 0.5212
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 5, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 34.48
# Test score scaling grid (grid object): 55.61
#
# VNQ gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 47.38%
# Train r2 score: 1.0000
# Test r2 score: -1.2526
# Test MSE: 1.1771
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 36.70
# Test score scaling grid (grid object): 26.18
#
# XLP gb classification model
#
# Train accuracy: 94.89%
# Test accuracy: 25.94%
# Train r2 score: 0.9175
# Test r2 score: -2.4949
# Test MSE: 2.1172
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 35.44
# Test score scaling grid (grid object): 45.14
#
# XRT gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 36.66%
# Train r2 score: 1.0000
# Test r2 score: -0.8133
# Test MSE: 1.2319
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 36.78
# Test score scaling grid (grid object): 49.13
#
# DIA gb classification model
#
# Train accuracy: 94.66%
# Test accuracy: 45.39%
# Train r2 score: 0.9176
# Test r2 score: 0.0255
# Test MSE: 0.5985
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 5, 'gb__n_estimators': 500}
# Best cross-validation score scaling grid: 31.97
# Test score scaling grid (grid object): 39.90
#
# IHI gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 41.90%
# Train r2 score: 1.0000
# Test r2 score: -1.1251
# Test MSE: 0.9776
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 34.10
# Test score scaling grid (grid object): 41.65
#
# IYW gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 41.65%
# Train r2 score: 1.0000
# Test r2 score: -0.2335
# Test MSE: 0.6733
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 40.37
# Test score scaling grid (grid object): 11.97
#
# SHY gb classification model
#
# Train accuracy: 96.08%
# Test accuracy: 12.22%
# Train r2 score: 0.9286
# Test r2 score: -5.2198
# Test MSE: 2.8529
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 30.94
# Test score scaling grid (grid object): 52.37
#
# VIS gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 52.37%
# Train r2 score: 1.0000
# Test r2 score: -0.2127
# Test MSE: 0.4763
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 44.84
# Test score scaling grid (grid object): 37.16
#
# XLE gb classification model
#
# Train accuracy: 97.90%
# Test accuracy: 37.16%
# Train r2 score: 0.9667
# Test r2 score: -1.2690
# Test MSE: 1.3466
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 10, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 33.00
# Test score scaling grid (grid object): 36.66
#
# XLF gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 39.65%
# Train r2 score: 1.0000
# Test r2 score: -0.0046
# Test MSE: 0.6035
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 29.85
# Test score scaling grid (grid object): 48.63
#
# XLK gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 50.37%
# Train r2 score: 1.0000
# Test r2 score: -0.2199
# Test MSE: 0.6983
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 5, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 31.24
# Test score scaling grid (grid object): 33.92
#
# XLU gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 25.44%
# Train r2 score: 1.0000
# Test r2 score: -1.9708
# Test MSE: 2.1072
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 41.47
# Test score scaling grid (grid object): 22.19
#
# XLV gb classification model
#
# Train accuracy: 95.29%
# Test accuracy: 22.94%
# Train r2 score: 0.9248
# Test r2 score: -1.9411
# Test MSE: 1.7955
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 1000}
# Best cross-validation score scaling grid: 37.25
# Test score scaling grid (grid object): 35.41
#
# XLY gb classification model
#
# Train accuracy: 100.00%
# Test accuracy: 34.91%
# Train r2 score: 1.0000
# Test r2 score: -1.4217
# Test MSE: 1.3840
# Best parameters scaling grid: {'gb__loss': 'deviance', 'gb__max_depth': 3, 'gb__n_estimators': 100}
# Best cross-validation score scaling grid: 42.52
# Test score scaling grid (grid object): 92.68
#
# SIL gb classification model
#
# Train accuracy: 96.92%
# Test accuracy: 92.68%
# Train r2 score: 0.9527
# Test r2 score: 0.3700
# Test MSE: 0.0732

# %%
# Run Random Forest model

#df_creator(tickers, 'rf', 'regression', create_csv=False)
#df_creator(tickers, 'rf', 'classification', create_csv=False)
# Out:
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# FXU rf regression model
#
# Train r2 score: 0.6693
# Test r2 score: -0.4971
# Test MSE: 0.0061
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# GDX rf regression model
#
# Train r2 score: 0.8842
# Test r2 score: -4.2747
# Test MSE: 0.0278
# {'sfm__threshold': 'median', 'rf__n_estimators': 1000, 'rf__max_features': 0.2, 'rf__max_depth': 4}
# KBE rf regression model
#
# Train r2 score: 0.5664
# Test r2 score: -0.2884
# Test MSE: 0.0112
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# RXI rf regression model
#
# Train r2 score: 0.7261
# Test r2 score: -0.2863
# Test MSE: 0.0054
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# VNQ rf regression model
#
# Train r2 score: 0.7268
# Test r2 score: -0.4598
# Test MSE: 0.0061
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLP rf regression model
#
# Train r2 score: 0.7068
# Test r2 score: -0.4568
# Test MSE: 0.0055
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XRT rf regression model
#
# Train r2 score: 0.8925
# Test r2 score: 0.0602
# Test MSE: 0.0086
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# DIA rf regression model
#
# Train r2 score: 0.7106
# Test r2 score: -0.4080
# Test MSE: 0.0049
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# IHI rf regression model
#
# Train r2 score: 0.7997
# Test r2 score: -0.7747
# Test MSE: 0.0055
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# IYW rf regression model
#
# Train r2 score: 0.7249
# Test r2 score: -0.1105
# Test MSE: 0.0064
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# SHY rf regression model
#
# Train r2 score: 0.8008
# Test r2 score: -0.8274
# Test MSE: 0.0000
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# VIS rf regression model
#
# Train r2 score: 0.7636
# Test r2 score: -0.0246
# Test MSE: 0.0043
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLE rf regression model
#
# Train r2 score: 0.8665
# Test r2 score: -0.9538
# Test MSE: 0.0193
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLF rf regression model
#
# Train r2 score: 0.7740
# Test r2 score: -1.0563
# Test MSE: 0.0123
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLK rf regression model
#
# Train r2 score: 0.6555
# Test r2 score: -0.1054
# Test MSE: 0.0055
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLU rf regression model
#
# Train r2 score: 0.7183
# Test r2 score: -0.1112
# Test MSE: 0.0050
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLV rf regression model
#
# Train r2 score: 0.7528
# Test r2 score: -1.2366
# Test MSE: 0.0063
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLY rf regression model
#
# Train r2 score: 0.7127
# Test r2 score: -0.2644
# Test MSE: 0.0058
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# SIL rf regression model
#
# Train r2 score: 0.9461
# Test r2 score: -0.4126
# Test MSE: 0.0032
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# FXU rf classification model
#
# Train accuracy: 84.27%
# Test accuracy: 23.19%
# Train r2 score: 0.7399
# Test r2 score: -1.8426
# Test MSE: 1.8753
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# GDX rf classification model
#
# Train accuracy: 81.54%
# Test accuracy: 34.16%
# Train r2 score: 0.6666
# Test r2 score: -1.4168
# Test MSE: 0.8678
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# KBE rf classification model
#
# Train accuracy: 78.88%
# Test accuracy: 42.64%
# Train r2 score: 0.4263
# Test r2 score: -1.0466
# Test MSE: 1.0823
# {'sfm__threshold': 'median', 'rf__n_estimators': 1000, 'rf__max_features': 0.2, 'rf__max_depth': 4}
# RXI rf classification model
#
# Train accuracy: 82.23%
# Test accuracy: 26.93%
# Train r2 score: 0.7318
# Test r2 score: -1.9807
# Test MSE: 1.1721
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# VNQ rf classification model
#
# Train accuracy: 81.71%
# Test accuracy: 57.61%
# Train r2 score: 0.7023
# Test r2 score: -0.6274
# Test MSE: 0.8504
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# XLP rf classification model
#
# Train accuracy: 78.82%
# Test accuracy: 52.37%
# Train r2 score: 0.6479
# Test r2 score: -0.9471
# Test MSE: 1.1796
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# XRT rf classification model
#
# Train accuracy: 84.95%
# Test accuracy: 44.89%
# Train r2 score: 0.7404
# Test r2 score: -0.8574
# Test MSE: 1.2618
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# DIA rf classification model
#
# Train accuracy: 78.25%
# Test accuracy: 34.66%
# Train r2 score: 0.6032
# Test r2 score: -0.3805
# Test MSE: 0.8479
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# IHI rf classification model
#
# Train accuracy: 79.95%
# Test accuracy: 25.19%
# Train r2 score: 0.6540
# Test r2 score: -2.0250
# Test MSE: 1.3915
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# IYW rf classification model
#
# Train accuracy: 78.59%
# Test accuracy: 24.19%
# Train r2 score: 0.5636
# Test r2 score: -0.8000
# Test MSE: 0.9825
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# SHY rf classification model
#
# Train accuracy: 81.91%
# Test accuracy: 10.72%
# Train r2 score: 0.4941
# Test r2 score: -5.3502
# Test MSE: 2.9127
# {'sfm__threshold': 'median', 'rf__n_estimators': 600, 'rf__max_features': 0.1, 'rf__max_depth': 4}
# VIS rf classification model
#
# Train accuracy: 82.74%
# Test accuracy: 37.41%
# Train r2 score: 0.7045
# Test r2 score: -1.2983
# Test MSE: 0.9027
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLE rf classification model
#
# Train accuracy: 89.10%
# Test accuracy: 37.16%
# Train r2 score: 0.8303
# Test r2 score: -1.2690
# Test MSE: 1.3466
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLF rf classification model
#
# Train accuracy: 82.57%
# Test accuracy: 39.40%
# Train r2 score: 0.6830
# Test r2 score: -0.0087
# Test MSE: 0.6060
# {'sfm__threshold': 'median', 'rf__n_estimators': 900, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLK rf classification model
#
# Train accuracy: 73.31%
# Test accuracy: 32.67%
# Train r2 score: 0.5702
# Test r2 score: -0.6337
# Test MSE: 0.9352
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLU rf classification model
#
# Train accuracy: 79.56%
# Test accuracy: 26.93%
# Train r2 score: 0.6702
# Test r2 score: -1.8864
# Test MSE: 2.0474
# {'sfm__threshold': 'median', 'rf__n_estimators': 1000, 'rf__max_features': 0.2, 'rf__max_depth': 4}
# XLV rf classification model
#
# Train accuracy: 79.56%
# Test accuracy: 35.66%
# Train r2 score: 0.6746
# Test r2 score: -1.2303
# Test MSE: 1.3616
# {'sfm__threshold': 'median', 'rf__n_estimators': 300, 'rf__max_features': 0.5, 'rf__max_depth': 4}
# XLY rf classification model
#
# Train accuracy: 76.32%
# Test accuracy: 32.42%
# Train r2 score: 0.6213
# Test r2 score: -1.5176
# Test MSE: 1.4389
# {'sfm__threshold': 'median', 'rf__n_estimators': 1000, 'rf__max_features': 0.2, 'rf__max_depth': 4}
# SIL rf classification model
#
# Train accuracy: 80.05%
# Test accuracy: 86.59%
# Train r2 score: 0.5542
# Test r2 score: -0.1549
# Test MSE: 0.1341

# %%
# Run SVM model

#df_creator(tickers, 'svm', 'regression', create_csv=False)
#df_creator(tickers, 'svm', 'classification', create_csv=False)
# Out:
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -29.54
# Test score scaling grid (grid object): -27.05
#
# FXU svm regression model
#
# Train r2 score: 0.3052
# Test r2 score: -0.2705
# Test MSE: 0.0052
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: -53.76
# Test score scaling grid (grid object): -861.04
#
# GDX svm regression model
#
# Train r2 score: 0.4645
# Test r2 score: -8.6104
# Test MSE: 0.0507
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 100, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -29.36
# Test score scaling grid (grid object): -8.74
#
# KBE svm regression model
#
# Train r2 score: 0.6856
# Test r2 score: -0.0874
# Test MSE: 0.0094
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -17.81
# Test score scaling grid (grid object): -0.79
#
# RXI svm regression model
#
# Train r2 score: 0.6075
# Test r2 score: -0.0079
# Test MSE: 0.0042
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 13.26
# Test score scaling grid (grid object): -78.44
#
# VNQ svm regression model
#
# Train r2 score: 0.5547
# Test r2 score: -0.7844
# Test MSE: 0.0075
# Best parameters scaling grid: {'svm__C': 0.001, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -13.42
# Test score scaling grid (grid object): -37.36
#
# XLP svm regression model
#
# Train r2 score: 0.0390
# Test r2 score: -0.3736
# Test MSE: 0.0052
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 37.25
# Test score scaling grid (grid object): -17.93
#
# XRT svm regression model
#
# Train r2 score: 0.8640
# Test r2 score: -0.1793
# Test MSE: 0.0108
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 100, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -22.96
# Test score scaling grid (grid object): -11.60
#
# DIA svm regression model
#
# Train r2 score: 0.1970
# Test r2 score: -0.1160
# Test MSE: 0.0039
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -23.88
# Test score scaling grid (grid object): -22.01
#
# IHI svm regression model
#
# Train r2 score: 0.5884
# Test r2 score: -0.2201
# Test MSE: 0.0038
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -10.73
# Test score scaling grid (grid object): -3.02
#
# IYW svm regression model
#
# Train r2 score: 0.4919
# Test r2 score: -0.0302
# Test MSE: 0.0059
# Best parameters scaling grid: {'svm__C': 0.001, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -135.52
# Test score scaling grid (grid object): -214.00
#
# SHY svm regression model
#
# Train r2 score: -0.1591
# Test r2 score: -2.1400
# Test MSE: 0.0001
# Best parameters scaling grid: {'svm__C': 10, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -0.42
# Test score scaling grid (grid object): -72.32
#
# VIS svm regression model
#
# Train r2 score: 0.6965
# Test r2 score: -0.7232
# Test MSE: 0.0072
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -62.70
# Test score scaling grid (grid object): -49.78
#
# XLE svm regression model
#
# Train r2 score: 0.6650
# Test r2 score: -0.4978
# Test MSE: 0.0148
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 100, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -37.38
# Test score scaling grid (grid object): -0.13
#
# XLF svm regression model
#
# Train r2 score: 0.5704
# Test r2 score: -0.0013
# Test MSE: 0.0060
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -11.44
# Test score scaling grid (grid object): -4.70
#
# XLK svm regression model
#
# Train r2 score: 0.4105
# Test r2 score: -0.0470
# Test MSE: 0.0052
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 1.76
# Test score scaling grid (grid object): -6.57
#
# XLU svm regression model
#
# Train r2 score: 0.3901
# Test r2 score: -0.0657
# Test MSE: 0.0048
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 10, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -61.73
# Test score scaling grid (grid object): -9.84
#
# XLV svm regression model
#
# Train r2 score: 0.4008
# Test r2 score: -0.0984
# Test MSE: 0.0031
# Best parameters scaling grid: {'svm__degree': 5, 'svm__kernel': 'poly'}
# Best cross-validation score scaling grid: -10.14
# Test score scaling grid (grid object): 0.68
#
# XLY svm regression model
#
# Train r2 score: 0.4612
# Test r2 score: 0.0693
# Test MSE: 0.0043
# Best parameters scaling grid: {'svm__C': 0.001, 'svm__gamma': 0.01, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: -41.66
# Test score scaling grid (grid object): -693.22
#
# SIL svm regression model
#
# Train r2 score: -0.0666
# Test r2 score: -6.9322
# Test MSE: 0.0180
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 44.53
# Test score scaling grid (grid object): 36.41
#
# FXU svm classification model
#
# Train accuracy: 81.03%
# Test accuracy: 36.41%
# Train r2 score: 0.6764
# Test r2 score: -1.1547
# Test MSE: 1.4214
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 50.74
# Test score scaling grid (grid object): 25.44
#
# GDX svm classification model
#
# Train accuracy: 70.47%
# Test accuracy: 25.44%
# Train r2 score: 0.2642
# Test r2 score: -2.0973
# Test MSE: 1.1122
# Best parameters scaling grid: {'svm__C': 1, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 39.11
# Test score scaling grid (grid object): 44.39
#
# KBE svm classification model
#
# Train accuracy: 60.70%
# Test accuracy: 44.39%
# Train r2 score: -0.1670
# Test r2 score: -0.9146
# Test MSE: 1.0125
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: 45.48
# Test score scaling grid (grid object): 22.69
#
# RXI svm classification model
#
# Train accuracy: 47.19%
# Test accuracy: 22.69%
# Train r2 score: -0.7596
# Test r2 score: -2.2598
# Test MSE: 1.2818
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: 41.11
# Test score scaling grid (grid object): 53.37
#
# VNQ svm classification model
#
# Train accuracy: 50.65%
# Test accuracy: 53.37%
# Train r2 score: 0.0062
# Test r2 score: -0.7086
# Test MSE: 0.8928
# Best parameters scaling grid: {'svm__C': 100, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: 40.09
# Test score scaling grid (grid object): 18.20
#
# XLP svm classification model
#
# Train accuracy: 76.49%
# Test accuracy: 18.20%
# Train r2 score: 0.5477
# Test r2 score: -3.0671
# Test MSE: 2.4638
# Best parameters scaling grid: {'svm__degree': 3, 'svm__kernel': 'poly'}
# Best cross-validation score scaling grid: 45.25
# Test score scaling grid (grid object): 33.17
#
# XRT svm classification model
#
# Train accuracy: 55.20%
# Test accuracy: 28.18%
# Train r2 score: -0.3586
# Test r2 score: -0.6408
# Test MSE: 1.1147
# Best parameters scaling grid: {'svm__degree': 1, 'svm__kernel': 'poly'}
# Best cross-validation score scaling grid: 49.45
# Test score scaling grid (grid object): 37.91
#
# DIA svm classification model
#
# Train accuracy: 42.42%
# Test accuracy: 26.93%
# Train r2 score: -0.9909
# Test r2 score: -1.9072
# Test MSE: 1.7855
# Best parameters scaling grid: {'svm__C': 0.001, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 40.60
# Test score scaling grid (grid object): 16.21
#
# IHI svm classification model
#
# Train accuracy: 40.60%
# Test accuracy: 16.21%
# Train r2 score: -1.1429
# Test r2 score: -2.9357
# Test MSE: 1.8105
# Best parameters scaling grid: {'svm__C': 0.001, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 40.09
# Test score scaling grid (grid object): 18.45
#
# IYW svm classification model
#
# Train accuracy: 40.09%
# Test accuracy: 18.45%
# Train r2 score: -1.1543
# Test r2 score: -2.7690
# Test MSE: 2.0574
# Best parameters scaling grid: {'svm__C': 0.1, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 51.02
# Test score scaling grid (grid object): 10.72
#
# SHY svm classification model
#
# Train accuracy: 57.57%
# Test accuracy: 10.72%
# Train r2 score: -0.5376
# Test r2 score: -5.4155
# Test MSE: 2.9426
# Best parameters scaling grid: {'svm__degree': 2, 'svm__kernel': 'poly'}
# Best cross-validation score scaling grid: 43.82
# Test score scaling grid (grid object): 33.17
#
# VIS svm classification model
#
# Train accuracy: 45.54%
# Test accuracy: 28.93%
# Train r2 score: -0.8189
# Test r2 score: -1.5713
# Test MSE: 1.0100
# Best parameters scaling grid: {'svm__C': 100, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 49.57
# Test score scaling grid (grid object): 37.16
#
# XLE svm classification model
#
# Train accuracy: 89.04%
# Test accuracy: 37.16%
# Train r2 score: 0.8320
# Test r2 score: -1.2690
# Test MSE: 1.3466
# Best parameters scaling grid: {'svm__C': 100, 'svm__gamma': 0.01, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 50.32
# Test score scaling grid (grid object): 39.90
#
# XLF svm classification model
#
# Train accuracy: 73.25%
# Test accuracy: 39.90%
# Train r2 score: 0.2666
# Test r2 score: -0.0004
# Test MSE: 0.6010
# Best parameters scaling grid: {'svm__degree': 3, 'svm__kernel': 'poly'}
# Best cross-validation score scaling grid: 41.68
# Test score scaling grid (grid object): 19.45
#
# XLK svm classification model
#
# Train accuracy: 48.04%
# Test accuracy: 22.69%
# Train r2 score: -0.6328
# Test r2 score: -2.4417
# Test MSE: 1.9701
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__gamma': 1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 34.99
# Test score scaling grid (grid object): 28.68
#
# XLU svm classification model
#
# Train accuracy: 46.45%
# Test accuracy: 28.68%
# Train r2 score: -0.2885
# Test r2 score: -1.3555
# Test MSE: 1.6708
# Best parameters scaling grid: {'svm__C': 10, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best cross-validation score scaling grid: 44.48
# Test score scaling grid (grid object): 46.13
#
# XLV svm classification model
#
# Train accuracy: 80.35%
# Test accuracy: 46.13%
# Train r2 score: 0.5819
# Test r2 score: 0.0687
# Test MSE: 0.5686
# Best parameters scaling grid: {'svm__C': 0.01, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: 46.82
# Test score scaling grid (grid object): 32.17
#
# XLY svm classification model
#
# Train accuracy: 46.85%
# Test accuracy: 32.17%
# Train r2 score: -0.6962
# Test r2 score: -1.5220
# Test MSE: 1.4414
# Best parameters scaling grid: {'svm__C': 100, 'svm__kernel': 'linear'}
# Best cross-validation score scaling grid: 42.35
# Test score scaling grid (grid object): 86.59
#
# SIL svm classification model
#
# Train accuracy: 77.99%
# Test accuracy: 86.59%
# Train r2 score: 0.5358
# Test r2 score: -0.1549
# Test MSE: 0.1341

# %%
t2 = time.time()
t = t2-t1
print("total time in minutes: {}".format(t/60))
print("total time in hours: {}".format(t/3600))
# Out:
# total time in minutes: 135.42916345993677
# total time in hours: 2.2571527243322795
